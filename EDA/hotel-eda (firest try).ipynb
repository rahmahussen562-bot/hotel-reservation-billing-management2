# %%
import pandas as pd
file_path = "/kaggle/input/datasets/gehanabdelhameed/hotel-data/hotel_booking.csv"
df = pd.read_csv(file_path)

# %%
#import diff libraries for analysis
#ex pandas data cleaning (manipulation)- numpy for mathematical -matplotlib and seaborn for charts
#Display for show diff table at the same time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns
df = pd.read_csv("/kaggle/input/datasets/gehanabdelhameed/hotel-data/hotel_booking.csv")
df.shape                # No of Report Rows and Columns
# Out:
# (119390, 36)

# %%
#head() show the first 5 rows in data
df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  customer_type  \
# 0                        0                     0       2  ...      Transient
# ...

# %%
#we have 36 columns use display max for show all the columns
#head() show the first 5 rows in data
pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
# 5  Resort Hotel            0         14               2015               July
# 6  Resort Hotel            0          0               2015               July
# 7  Resort Hotel            0          9               2015               July
# 8  Resort Hotel            1         85               2015               July
# 9  Resort Hotel            1         75               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# ...

# %%
df.info()  # show all data type and not null with their column names to revise the correctiveness of their types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df['is_canceled'] = df['is_canceled'].astype(str)
df['is_repeated_guest'] = df['is_repeated_guest'].astype(object)
df['agent'] = df['agent'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  object
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %%
df.columns #show all  columns name
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card'],
#       dtype='object')

# %% [markdown]
# """hotel :: Type of hotel (Resort or City); categorical; limited values
#
# is_canceled:: Whether booking was canceled or not ( mapping 0 = no, 1 = yes); object
#
# lead_time:: Days between booking and arrival; Numeric; non-negative
#
# arrival_date_year:: Year of arrival; Date; non-negative
#
# arrival_date_month:: Month of arrival; categorical; Limited values
#
# arrival_date_week_number:: Week number of arrival; numeric; non-negative
#
# arrival_date_day_of_month:: Day of the month for arrival; numeric; non-negative
#
# stays_in_weekend_nights:: Number of weekend nights stayed; numeric; non-negative
#
# stays_in_week_nights:: Number of week nights stayed; numeric; non-negative
#
# adults:: Number of adults; numeric; non-negative,usually ≥1
#
# children:: Number of children; numeric; non-negative,can be 0
#
# babies:: Number of babies; numeric; non-negative,can be 0
#
# meal:: Type of meal booked; categorical; limited predefined categories (BB, HB, FB, SC)
#
# country:: Country of origin; categorical; Limited values
#
# market_segment:: Market segment of booking; categorical; limited predefined categories
#
# distribution_channel:: Booking distribution channel; categorical; limited values (Direct,TA,Corporate)
#
# is_repeated_guest:: Whether guest is returning; object 0,1
#
# previous_cancellations:: Number of previous cancellations; numeric; non-negative
#
# previous_bookings_not_canceled:: Number of previous bookings not canceled; numeric; non-negative
#
# reserved_room_type:: Code of reserved room type; categorical; limited values
#
# assigned_room_type:: Code of assigned room type; categorical; limited values
#
# booking_changes:: Number of changes made to the booking; numeric; non-negative
#
# deposit_type:: Type of deposit (No Deposit,Refundable,Non-refundable); categorical; limited values
#
# agent:: ID of travel agent; object; non-negative, unknown if direct booking
#
# company:: ID of company; numeric; non-negative, unknown if individual booking
#
# days_in_waiting_list:: Days in waiting list before confirmation; numeric; non-negative
#
# customer_type:: Type of customer (Contract,Transient,Transient-Party,Group); categorical; limited values
#
# adr:: Average daily rate (price); numeric; non-negative, outliers possible
#
# required_car_parking_spaces:: Number of requested parking spaces; Numeric(Boolean): Limited values (0,1)
#
# total_of_special_requests:: Number of special requests made; numeric; non-negative
#
# reservation_status:: Status of the reservation at dataset export; categorical; limited values (Canceled,Check-Out,No-Show)
#
# reservation_status_date:: Date of last status change; date; valid date format
#
# name:: Guest name; text; mostly unique per booking
#
# email:: Guest email; text; mostly unique
#
# phone-number:: Guest phone number; text; mostly unique
#
# credit_card:: Credit card number; text ; mostly unique, sensitive info"""

# %%
df.duplicated().sum() #count of duplicated rows in data appeared as there is no duplicate in data
# Out:
# np.int64(0)

# %%
#show the datatypes of all data
df.dtypes
# Out:
# hotel                              object
# is_canceled                        object
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                  object
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# """is cancelled and is repeated guest :: were int type while they are categorical data (0,1) -- will converted to object
# reservation_status_date:: Categorical data(object) and we will change it to Datetime
# arrival_date_year+arrival_date_month+arrival_date_day_of_month collect them into one new column and change it to datetime"""

# %%
#Show the number of missing values per column(sorted, excluding zero values)
missing_values = df.isnull().sum()
print('The missing values of the data (sorted by count):')
print(missing_values[missing_values > 0].sort_values(ascending=False))
# Out:
# The missing values of the data (sorted by count):
# company     112593
# agent        16340
# country        488
# children         4
# dtype: int64

# %%
#Show the percentage of missing values for each column
missing_percent = (df.isna().sum() / len(df) * 100).sort_values(ascending=False)
print(missing_percent[missing_percent >0])
# Out:
# company     94.306893
# agent       13.686238
# country      0.408744
# children     0.003350
# dtype: float64

# %%
df['reservation_status_date'] = df['reservation_status_date'].astype('datetime64[ns]') #change object to datetime
print(df[['reservation_status_date']].head(10))
print(df['reservation_status_date'].dtype)
# Out:
#   reservation_status_date
# 0              2015-07-01
# 1              2015-07-01
# 2              2015-07-02
# 3              2015-07-02
# 4              2015-07-03
# 5              2015-07-03
# 6              2015-07-03
# 7              2015-07-03
# 8              2015-05-06
# 9              2015-04-22
# datetime64[ns]

# %%
#collect all date at the same column (yyyy,mm,dd)
df['Total_arrival_date'] = pd.to_datetime(
    df['arrival_date_year'].astype(str) + '-' +
    df['arrival_date_month'] + '-' +
    df['arrival_date_day_of_month'].astype(str),
    format='%Y-%B-%d',
    errors='coerce')
print(df[['Total_arrival_date']].head(10))
print(df['Total_arrival_date'].dtype)
# Out:
#   Total_arrival_date
# 0         2015-07-01
# 1         2015-07-01
# 2         2015-07-01
# 3         2015-07-01
# 4         2015-07-01
# 5         2015-07-01
# 6         2015-07-01
# 7         2015-07-01
# 8         2015-07-01
# 9         2015-07-01
# datetime64[ns]

# %%
# Replace missing 'agent' values with the label 'Unknown'
df['agent']= df['agent'].fillna('Unknown')

# %%
#now there is no null data
missing_values = df.isnull().sum()
print('The missing values of the data (sorted by count):')
print(missing_values[missing_values > 0].sort_values(ascending=False))
# Out:
# The missing values of the data (sorted by count):
# company     112593
# country        488
# children         4
# dtype: int64

# %%
df.dtypes #show the datatypes of all data
# Out:
# hotel                                     object
# is_canceled                               object
# lead_time                                  int64
# arrival_date_year                          int64
# arrival_date_month                        object
# arrival_date_week_number                   int64
# arrival_date_day_of_month                  int64
# stays_in_weekend_nights                    int64
# stays_in_week_nights                       int64
# adults                                     int64
# children                                 float64
# babies                                     int64
# meal                                      object
# country                                   object
# market_segment                            object
# distribution_channel                      object
# is_repeated_guest                         object
# previous_cancellations                     int64
# previous_bookings_not_canceled             int64
# ...

# %%
df.drop(['company'], axis=1, inplace=True, errors='ignore') #94% missing values so it is not imp we can drop column
df.dropna(subset=['children'], inplace=True) #4 cases only tiny so we drop it

# %%
#change type after removing nan
df['children'] = df['children'].astype(int)

# %%
#Handle missing values in 'agent' by filling them with the median  (it is numeric)
df['country'] = df['country'].fillna('Unknown')

# %%
df.dtypes

# %%
df.duplicated().sum() #count of duplicated rows in data appeared as there is no duplicate in numeric data
# Out:
# np.int64(0)

# %%
#count of duplicated rows in data appeared as there is no duplicate in categorical data
categorical_cols = df.select_dtypes(include=['object']).columns
duplicate_cat_rows = df.duplicated(subset=categorical_cols).sum()
print(duplicate_cat_rows)
# Out:
# 0

# %%
df.nunique() #Show the count of unique values per column
# Out:
# hotel                                  2
# is_canceled                            2
# lead_time                            479
# arrival_date_year                      3
# arrival_date_month                    12
# arrival_date_week_number              53
# arrival_date_day_of_month             31
# stays_in_weekend_nights               17
# stays_in_week_nights                  35
# adults                                14
# children                               5
# babies                                 5
# meal                                   5
# country                              178
# market_segment                         7
# distribution_channel                   5
# is_repeated_guest                      2
# previous_cancellations                15
# previous_bookings_not_canceled        73
# reserved_room_type                    10
# assigned_room_type                    12
# booking_changes                       21
# deposit_type                           3
# ...

# %%
df.describe() #Descriptive statistics of numerical columns
# Out:
#            lead_time  arrival_date_year  arrival_date_week_number  \
# count  119386.000000      119386.000000             119386.000000
# mean      104.014801        2016.156593                 27.165003
# min         0.000000        2015.000000                  1.000000
# 25%        18.000000        2016.000000                 16.000000
# 50%        69.000000        2016.000000                 28.000000
# 75%       160.000000        2017.000000                 38.000000
# max       737.000000        2017.000000                 53.000000
# std       106.863286           0.707456                 13.605334
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count              119386.000000            119386.000000
# mean                   15.798553                 0.927605
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# 50%                    16.000000                 1.000000
# ...

# %%
"""Validity rules: are there impossible values?

Negative amounts: adr column has 1 negative value (-6.38), which is impossible for a room rate.

Future dates: reservation_status_date maximum is 2017-09-14 (within data range 2015–2017), no future dates.

Impossible guest counts: adults = 0 in 403 rows (impossible to have a booking with no adults, 
 especially when children and babies are also 0 in most cases). Violation counts: Negative adr: 1 Zero adults: 403"""

# %%
negative_adr = df[df['adr'] < 0]  # -ve value in adr(price) we will drop it because it is unlogical data (invalid)
print(f"negative_values: {len(negative_adr)}")
display(negative_adr)
# Out:
# negative_values: 1
#               hotel is_canceled  lead_time  arrival_date_year  \
# 14969  Resort Hotel           0        195               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14969              March                        10                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 14969                        4                     6       2         0
#
#        babies meal country market_segment distribution_channel  \
# 14969       0   BB     GBR         Groups               Direct
#
#       is_repeated_guest  previous_cancellations  \
# 14969                 1                       0
#
#        previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 14969                               2                  A                  H
#
#        booking_changes deposit_type  agent  days_in_waiting_list  \
# ...

# %%
df.drop(negative_adr.index, inplace=True,errors='ignore')

# %%
display(negative_adr)
# Out:
#               hotel is_canceled  lead_time  arrival_date_year  \
# 14969  Resort Hotel           0        195               2017
#
#       arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 14969              March                        10                          5
#
#        stays_in_weekend_nights  stays_in_week_nights  adults  children  \
# 14969                        4                     6       2         0
#
#        babies meal country market_segment distribution_channel  \
# 14969       0   BB     GBR         Groups               Direct
#
#       is_repeated_guest  previous_cancellations  \
# 14969                 1                       0
#
#        previous_bookings_not_canceled reserved_room_type assigned_room_type  \
# 14969                               2                  A                  H
#
#        booking_changes deposit_type  agent  days_in_waiting_list  \
# 14969                2   No Deposit  273.0                     0
#
# ...

# %%
df = df.rename(columns={'adr': 'price as Average daily rate'})  #rename the column to understand 
print(df.columns)
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'days_in_waiting_list', 'customer_type', 'price as Average daily rate',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date', 'name', 'email',
#        'phone-number', 'credit_card', 'Total_arrival_date'],
#       dtype='object')

# %%
#there is no future date after 2017
future_dates = df[df['reservation_status_date'].dt.year > 2017]
print(future_dates)
# Out:
# Empty DataFrame
# Columns: [hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, arrival_date_week_number, arrival_date_day_of_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, meal, country, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, previous_bookings_not_canceled, reserved_room_type, assigned_room_type, booking_changes, deposit_type, agent, days_in_waiting_list, customer_type, price as Average daily rate, required_car_parking_spaces, total_of_special_requests, reservation_status, reservation_status_date, name, email, phone-number, credit_card, Total_arrival_date]
# Index: []

# %%
#show number of rows before dealing with outliers
initial_rows = len(df)
print(len(df))
# Out:
# 119385

# %%
#Negative_amount
unexpected_adults = df[df['adults'] > 10] #the room couldnot afford more than 10 persons at the same time
neg_adults = df[df['adults'] <= 0]     # -ve no of people isnot reliable
neg_children = df[df['children'] < 0]  # -ve no of children isnot reliable
neg_babies = df[df['babies'] < 0]     # -ve no of children isnot reliable
zero_guests = df[(df['adults'] + df['children'] + df['babies']) == 0]
print(f"Negative Adults: {len(neg_adults)}")
print(f"neg_children: {len(neg_children)}")
print(f"neg_babies: {len(neg_babies)}")
print(f"Unusual high number of adults (>10): {len(unexpected_adults)}")
print(f"Zero Total Guests violations: {len(zero_guests)}")
display(zero_guests[['adults', 'children', 'babies']].head())
#print(f"neg_adults:{neg_adults},neg_children:{neg_children},neg_babies:{neg_babies},zero_guests:{zero_guests}")
# Out:
# Negative Adults: 403
# neg_children: 0
# neg_babies: 0
# Unusual high number of adults (>10): 12
# Zero Total Guests violations: 180
#       adults  children  babies
# 2224       0         0       0
# 2409       0         0       0
# 3181       0         0       0
# 3684       0         0       0
# 3708       0         0       0

# %%
#remove the invalid data (adult,children and babies with negative + adult more than 10)
df_new = df[
    (df['adults'] > 0) &           
    (df['adults'] <= 10) &           
    (df['children'] >= 0) &          
    (df['babies'] >= 0) &           
    ((df['adults'] + df['children'] + df['babies']) > 0) 
].copy()

# %%
initial_rows = len(df)
rows_dropped = initial_rows - len(df_new)
print(f"No of dropped row :{rows_dropped}")
# Out:
# No of dropped row :415

# %%
df_new.head()
# Out:
#           hotel is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel           0        342               2015               July
# 1  Resort Hotel           0        737               2015               July
# 2  Resort Hotel           0          7               2015               July
# 3  Resort Hotel           0         13               2015               July
# 4  Resort Hotel           0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  children  babies  \
# 0                        0                     0       2         0       0
# ...

# %%
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 118970 entries, 0 to 119389
# Data columns (total 36 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           118970 non-null  object
#  1   is_canceled                     118970 non-null  object
#  2   lead_time                       118970 non-null  int64
#  3   arrival_date_year               118970 non-null  int64
#  4   arrival_date_month              118970 non-null  object
#  5   arrival_date_week_number        118970 non-null  int64
#  6   arrival_date_day_of_month       118970 non-null  int64
#  7   stays_in_weekend_nights         118970 non-null  int64
#  8   stays_in_week_nights            118970 non-null  int64
#  9   adults                          118970 non-null  int64
#  10  children                        118970 non-null  int64
#  11  babies                          118970 non-null  int64
# ...

# %% [markdown]
# After cleaning, the number of unique categories in some columns decreased, proving that there were redundant labels caused by formatting issues.
#
# like name email phone for one case

# %%
# Apply standard cleaning: strip spaces and convert to uppercase
categorical_cols = df_new.select_dtypes(include=['object']).columns
for col in categorical_cols:
 df_new.loc[:, col] = df_new[col].astype(str).str.strip().str.upper() 
 print(f"Unique values in {col}:")
 print(df[col].unique())
# Out:
# Unique values in hotel:
# ['Resort Hotel' 'City Hotel']
# Unique values in is_canceled:
# ['0' '1']
# Unique values in arrival_date_month:
# ['July' 'August' 'September' 'October' 'November' 'December' 'January'
#  'February' 'March' 'April' 'May' 'June']
# Unique values in meal:
# ['BB' 'FB' 'HB' 'SC' 'Undefined']
# Unique values in country:
# ['PRT' 'GBR' 'USA' 'ESP' 'IRL' 'FRA' 'Unknown' 'ROU' 'NOR' 'OMN' 'ARG'
#  'POL' 'DEU' 'BEL' 'CHE' 'CN' 'GRC' 'ITA' 'NLD' 'DNK' 'RUS' 'SWE' 'AUS'
#  'EST' 'CZE' 'BRA' 'FIN' 'MOZ' 'BWA' 'LUX' 'SVN' 'ALB' 'IND' 'CHN' 'MEX'
#  'MAR' 'UKR' 'SMR' 'LVA' 'PRI' 'SRB' 'CHL' 'AUT' 'BLR' 'LTU' 'TUR' 'ZAF'
#  'AGO' 'ISR' 'CYM' 'ZMB' 'CPV' 'ZWE' 'DZA' 'KOR' 'CRI' 'HUN' 'ARE' 'TUN'
#  'JAM' 'HRV' 'HKG' 'IRN' 'GEO' 'AND' 'GIB' 'URY' 'JEY' 'CAF' 'CYP' 'COL'
#  'GGY' 'KWT' 'NGA' 'MDV' 'VEN' 'SVK' 'FJI' 'KAZ' 'PAK' 'IDN' 'LBN' 'PHL'
#  'SEN' 'SYC' 'AZE' 'BHR' 'NZL' 'THA' 'DOM' 'MKD' 'MYS' 'ARM' 'JPN' 'LKA'
# ...

# %%
df.nunique() #Show the count of unique values per column
# Out:
# hotel                                  2
# is_canceled                            2
# lead_time                            479
# arrival_date_year                      3
# arrival_date_month                    12
# arrival_date_week_number              53
# arrival_date_day_of_month             31
# stays_in_weekend_nights               17
# stays_in_week_nights                  35
# adults                                14
# children                               5
# babies                                 5
# meal                                   5
# country                              178
# market_segment                         7
# distribution_channel                   5
# is_repeated_guest                      2
# previous_cancellations                15
# previous_bookings_not_canceled        73
# reserved_room_type                    10
# assigned_room_type                    12
# booking_changes                       21
# deposit_type                           3
# ...

# %%
#Univariate EDA (Single Column Insights)

# %%
df_new.describe()
# Out:
#            lead_time  arrival_date_year  arrival_date_week_number  \
# count  118970.000000      118970.000000             118970.000000
# mean      104.049407        2016.156510                 27.162949
# min         0.000000        2015.000000                  1.000000
# 25%        18.000000        2016.000000                 16.000000
# 50%        69.000000        2016.000000                 28.000000
# 75%       160.000000        2017.000000                 38.000000
# max       737.000000        2017.000000                 53.000000
# std       106.870190           0.707661                 13.599146
#
#        arrival_date_day_of_month  stays_in_weekend_nights  \
# count              118970.000000            118970.000000
# mean                   15.797571                 0.926864
# min                     1.000000                 0.000000
# 25%                     8.000000                 0.000000
# 50%                    16.000000                 1.000000
# ...

# %% [markdown]
# ## """In lead_time::  the Mean (104) is much higher than the Median (69). This make the data is Positive-Skewed with outliers;
# "very early" bookings are pulling the average up.
# stays_in_week_nights::  the max values for stays_in_week_nights (50). mean 2.5 These might be "outliers" (extreme cases)
# is_canceled:: The mean is 0.37, which means approximately 37% of all bookings rate were canceled.
# Children::   Most bookings do not include children. Notice that the 25th, 50th (median), and 75th percentiles are all 0.00
# adr(price)::  The average price is 102, but the 5400 max - may be the difference in price is very high or outlier
# days_in_waiting_list ::  Most people wait 0 days, though the maximum wait time was 391 days.(skewed)
# is_repeated_guest::   Only 3% of your customers are returning guests
# #booking_changes::The mean is 0.2, while the maximum value is 18.
# previous_Cancellations::  Most guests have 0 previous cancellations, but some went up to 26."""

# %%
numeric_cols = df_new.select_dtypes(include=['number']).columns
for col in numeric_cols:
    plt.figure(figsize=(8, 4)) 
    sns.histplot(df_new[col], kde=True, color='teal') # ارسم الـ Histogram
    
    plt.title(f'Distribution of {col}') 
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %% [markdown]
# Lead Time:: The data is right-skewed, showing that most guests book shortly before arrival
# ADR:: Most rates are concentrated around 200, but the presence of a 5400 value indicates a significant outlier  but accepted as it may happened in expensive sweet
# Days in Waiting List:: Over 75% of bookings are confirmed immediately (0 days), with very few cases facing long waiting period
# Total Special Requests:: The majority of guests make zero or one special request, showing a low demand for extra services per booking
# Previous Cancellations:: Most customers have no history of cancellation

# %% [markdown]
# Distribution of lead_time
# Distribution of stay in weekend_nights
# Distribution of stay in week_nights
# Distribution of adults,children and babies
# Distribution of previous_cancellations
# Distribution of previous_bookings_not_canceled
# Distribution of booking_changes
# Distribution of days_in_waiting_list
# Distribution of price as Average daily rate
# Distribution of required_car_parking_spaces
# Distribution of total_of_special_requests
# Skewed Distribution

# %%
df_new['lead_time_log'] = np.log1p(df_new['lead_time'])
df_new['previous_cancellations_log'] = np.log1p(df_new['previous_cancellations'])
df_new['previous_bookings_not_canceled_log'] = np.log1p(df_new['previous_bookings_not_canceled'])
df_new['booking_changes_log'] = np.log1p(df_new['booking_changes'])
df_new['days_in_waiting_list_log'] = np.log1p(df_new['days_in_waiting_list'])
df_new['price as Average daily rate_log'] = np.log1p(df_new['price as Average daily rate'])
df_new['required_car_parking_spaces_log'] = np.log1p(df_new['required_car_parking_spaces'])
df_new['total_of_special_requests_log'] = np.log1p(df_new['total_of_special_requests'])

# %%
log_cols = [col for col in df_new.columns if col.endswith('_log')]

for col in log_cols:
    plt.figure(figsize=(8, 4)) 
    # Plotting the histogram with a Kernel Density Estimate (KDE)
    sns.histplot(df_new[col], kde=True, color='teal') 
    
    plt.title(f'Distribution of {col}') 
    plt.xlabel(col)
    plt.ylabel('Frequency')
    plt.show()

# %%
cols_to_plot = [ 'lead_time', 'previous_cancellations', 'previous_bookings_not_canceled',
    'booking_changes', 'days_in_waiting_list', 'price as Average daily rate',
    'required_car_parking_spaces', 'total_of_special_requests']
for col in cols_to_plot:
    log_col = f"{col}_log"  #specify the name of cloumn
    fig, axes = plt.subplots(1, 2, figsize=(15, 4))
    #before log
    sns.boxplot(x=df_new[col], ax=axes[0], color='salmon')
    axes[0].set_title(f'Original: {col}')
    #after log
    sns.boxplot(x=df_new[log_col], ax=axes[1], color='teal')
    axes[1].set_title(f'Log Transformed: {log_col}')
    
    plt.tight_layout()
    plt.show()

# %%
outliers = df_new[df_new['price as Average daily rate'] > 5000]  #not outlier we will keep it and make log
print(outliers[['price as Average daily rate']])
# Out:
#        price as Average daily rate
# 48515                       5400.0

# %%
#show the line with max rate that made the outlier
max_price_row = df_new.loc[[df_new['price as Average daily rate'].idxmax()]] 

max_price_row

# %%
"""fig, axes = plt.subplots(1, 2, figsize=(16, 5))

sns.boxplot(x=df_new['lead_time_log'], ax=axes[1], color='teal')
axes[1].set_title('Box Plot: Lead Time (Log Transformed)')
axes[1].set_xlabel('Lead Time (Log)')

# تحسين مظهر الرسم ومنع تداخل العناوين
plt.tight_layout()
plt.show()"""

# %%
zero_adr = df_new[df_new['price as Average daily rate'] == 0]  #not logic remove them from data to make the mean represent the average of price 
display(zero_adr.head(10))

# %%
df_new = df_new[df_new['price as Average daily rate'] > 0]

# %%
cols_to_plot = [ 'days_in_waiting_list']
plt.figure(figsize=(10, 6))
sns.boxplot(data=df_new[cols_to_plot], palette="Set2")
plt.title("Boxplots  Days in Waiting List")
plt.ylabel("Values")
plt.show()

# %%
df.info()

# %%
df_new['total_stay'] = df_new['stays_in_week_nights'] + df_new['stays_in_weekend_nights']

# %%
outliers = df_new[df_new['total_stay'] > 60]  #try diff no to see the outliers 20,30,40,50,60
print(outliers[['total_stay']])

# %%
top_5_stays = df_new.nlargest(5, 'total_stay')

top_5_stays

# %%
df_new['is_canceled'] = df_new['is_canceled'].map({0: 'Not Canceled', 1: 'Canceled'})
plt.figure(figsize=(6, 4))
sns.countplot(x='is_canceled', data=df_new, palette='viridis', hue='is_canceled')
plt.title('Count of Canceled vs Non-Canceled Bookings')
plt.show()

# %%
df_new['lead_time_log'] = np.log1p(df_new['lead_time']) # we made log for lead time to be normal distribution

# %%
#Lead Time: Heavily positive-skewed with a long tail, indicating most bookings are made closer to arrival
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

#(Original Lead Time)(skewed)
sns.histplot(df_new['lead_time'], kde=True, ax=axes[0], color='red')
axes[0].set_title('Before: Original Lead Time (Positive Skew)')

#(Log Transformed)(normal distribution )
sns.histplot(df_new['lead_time_log'], kde=True, ax=axes[1], color='green')
axes[1].set_title('After: Log Transformed (Approaching Normal)')

plt.show()

# %%
df_new['total_stay'] = df_new['stays_in_week_nights'] + df_new['stays_in_weekend_nights'] # we made one column for all stay even in week or weekend

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=df_new['total_stay'], color='red')
plt.title('Outliers in total stay (total_stay)')
plt.show()

# %%
df_new['price_log'] = np.log1p(df_new['price as Average daily rate']) # we made log for lead time to be normal distribution

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

#(Original Lead Time)(skewed)
sns.histplot(df_new['price as Average daily rate'], kde=True, ax=axes[0], color='red')
axes[0].set_title('Before: Original price as Average daily rate (Positive Skew)')

#(Log Transformed)(normal distribution )
sns.histplot(df_new['price_log'], kde=True, ax=axes[1], color='green')
axes[1].set_title('After: Log Transformed (Approaching Normal)')

plt.show()

# %%
ADR (Price): Roughly normal distribution but centered around 100, with extreme outliers on the right side (high-priced rooms).

Stays in Week/Weekend Nights: Both are discrete and skewed, showing that most guests stay for 1-3 nights, with very few long-term stays.

Total Stay (if created): Follows a log-normal pattern, where short stays are the norm and long stays are rare outliers.

Previous Cancellations: Extremely unbalanced/skewed; the vast majority of values are 0, showing that repeat-cancelers are a tiny minority.

# %%
cols_to_plot = ['lead_time_log', 'price as Average daily rate', 'total_stay','is_canceled', 'arrival_date_day_of_month',
                'total_of_special_requests','required_car_parking_spaces','days_in_waiting_list','agent','booking_changes','arrival_date_year',
                'previous_bookings_not_canceled','previous_cancellations','is_repeated_guest','adults','children','babies',]

plt.figure(figsize=(20,45))
for i, col in enumerate(cols_to_plot, 1):
    plt.subplot(9, 2, i)
    sns.histplot(df_new[col], kde=True, bins=30, color='skyblue')
    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
"""adr: (Cap) To handle extreme price spikes (like the 5000+ value) that skew the average

Lead Time: (Cap) Some bookings are made more than 500 days in advance. Capping helps the model without losing the fact that it's a long-term booking.

Stays in weekend/week nights: (Keep) Long stays ( 14+ nights) are realistic in the hotel industry and represent actual guest behavior

Previous Cancellations: (Keep) High values indicate "risky" guests. This is a critical feature for predicting cancellations and should not be modified"""

# %%
"""
Boxplots Visualization: As shown in the plots above, several columns exhibit extreme values (Outliers), particularly in adr and lead_time.

Outlier-heavy Columns: adr, lead_time, and stays_in_week_nights.
"""

# %%
numeric_cols = ['lead_time_log', 'adr', 'total_stay','is_canceled', 'arrival_date_day_of_month',
                'total_of_special_requests','required_car_parking_spaces','days_in_waiting_list','agent','booking_changes','arrival_date_year',
                'previous_bookings_not_canceled','previous_cancellations','is_repeated_guest','adults','children','babies']
plt.figure(figsize=(15, 10))
for i, col in enumerate(numeric_cols, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(x=df_new[col], color='skyblue')
    plt.title(f'Outliers in {col}')

plt.tight_layout()
plt.show()

# %%
#Define categorical columns for analysis
categorical_columns = df_new.select_dtypes(include=['object']).columns
for col in categorical_columns:
    print(f"Top 10 categories in '{col}' -")
    print(df_new[col].value_counts().head(10))  #descending by defualt
    print("\n") #to make space line between each column

# %%
plt.figure(figsize=(10, 5))

#before grouping
sns.countplot(x='market_segment', data=df_new, palette='viridis', hue='market_segment', legend=False)
plt.title('Market Segment Distribution (befor Grouping Rare Categories)')
plt.xticks(rotation=45)
plt.show()

# %%
#Define categorical columns for analysis
categorical_columns = categorical_columns.drop(['name','email'], errors='ignore') 
#name is excluded as it contains unique values (High Cardinality)to avoid treating every unique person as a 'rare category
# Loop through each column to identify rare categories
for col in categorical_columns:
    # Calculate the frequency as a percentage
    relative_freq = df_new[col].value_counts(normalize=True) * 100

    # Filter categories that appear in less than 3%
    rare_categories = relative_freq[relative_freq < 3]

    if not rare_categories.empty:
        print(f"Column: [{col}]")
        for category, percentage in rare_categories.items():
            print(f" - Category '{category}': {percentage:.2f}%")
       
        df_new[col] = df_new[col].replace(rare_categories.index, 'Other')
        
        print(f" >> Decision: Grouped into 'Other' successfully.")
        print("-" * 30)
    else:
        print(f"Column: [{col}] - No rare categories found.")
        print("-" * 30)

# %%
plt.figure(figsize=(10, 5))

#after grouping
sns.countplot(x='market_segment', data=df_new, palette='viridis', hue='market_segment', legend=False)
plt.title('Market Segment Distribution (After Grouping Rare Categories)')
plt.xticks(rotation=45)
plt.show()

# %%
#Multivariate

# %%
#Although price variation is natural, the value of 5000 was identified as an extreme outlier/error.
#Removing it improved the data distribution and ensured our correlation
df_new = df_new[df_new['adr'] < 800]

# %%
"""After removing the extreme price outlier (adr > 800), the correlation coefficients between adr and guest-related features (adults, children) increased. 
This indicates that the outlier was skewing the statistical relationships and its removal provided a more accurate representation of the hotel's pricing logic."""

# %%
corr_matrix = df_new.corr(numeric_only=True) #it work only on numeric columns
#heatmap show the correlation 

plt.figure(figsize=(12, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix of Numeric Features')
plt.show()

# %%
sol = corr_matrix.unstack()# to be able to sort them
sorted_sol = sol.sort_values(ascending=False)
top_positive = sorted_sol[sorted_sol < 1].drop_duplicates().head(5)  #the top 5 descending by default
top_negative = sol.sort_values(ascending=True).drop_duplicates().head(5) #the top 5 ascending 

print(f"Top 5 Strongest Positive Correlations:{top_positive}")
print(f"Top 5 Strongest negative Correlations:{top_negative}")

# %%
"""Top 5 Strongest Correlation Pairs:

arrival_date_year & arrival_date_week_number (-0.54): This negative correlation reflects how bookings are distributed across different seasons and weeks over the years.

stays_in_week_nights & stays_in_weekend_nights (0.49): A strong positive correlation indicating that guests who stay during the week are highly likely to extend their visit through the weekend.

is_repeated_guest & previous_bookings_not_canceled (0.42): A clear positive link showing that guests who successfully completed previous stays are the most likely to become loyal, repeat customers.

price (adr) & children (0.35): A positive correlation revealing that family bookings with children significantly drive up the average daily rate (room price).

is_canceled & lead_time (0.29): A critical positive correlation for the business; as the time between booking and arrival increases, the probability of cancellation also rises."""

# %%
"A few outliers are visible, such as bookings with high adult counts but zero ADR, which might indicate promotional or group booking anomalies."

# %%
fig, axes = plt.subplots(1, 4, figsize=(16, 6))

sns.scatterplot(data=df_new, x='stays_in_week_nights', y='stays_in_weekend_nights', alpha=0.5, ax=axes[0], color='blue')
axes[0].set_title('Relationship: Week Nights vs. Weekend Nights')

sns.scatterplot(data=df_new, x='adults', y='adr', alpha=0.5, ax=axes[1], color='green')
axes[1].set_title('Relationship: Adults vs. Price (ADR)')

sns.scatterplot(data=df_new, x='is_canceled', y='lead_time', alpha=0.5, ax=axes[2], color='Black')
axes[2].set_title('is_canceled vs. lead_time')

sns.scatterplot(data=df_new, x='is_repeated_guest', y='previous_bookings_not_canceled', alpha=0.5, ax=axes[3], color='Red')
axes[3].set_title('Relationship: is_repeated_guest vs. previous_bookings_not_canceled')


plt.tight_layout()
plt.show()

# %%
1. Week Nights vs. Weekend Nights:
The scatter plot shows a strong, linear upward trend. This confirms that guests who book longer stays tend to balance their time between weekdays and weekends. There is a clear "diagonal" pattern, meaning as one increases, the other follows closely.

2. Adults vs. Price (ADR):
The plot reveals that the majority of bookings are concentrated around 1 to 2 adults. We can observe that as the number of adults increases, the price range (adr) tends to shift upward, confirming that occupancy is a key driver for room pricing.

3. Is_canceled vs. Lead_time:
Although is_canceled is a discrete variable (0 or 1), the vertical density shows that cancellations (1.0) are very frequent across all lead_time values. However, many of the extreme long-term bookings (high lead time) end up in the "canceled" category, supporting our finding that long lead times increase cancellation risk.

4. Is_repeated_guest vs. Previous_bookings_not_canceled:
The plot shows a vertical line at is_repeated_guest = 1, where we see a high number of previous successful bookings. This visually proves that repeat guests are those who have a strong history of visiting the hotel without canceling.

# %%
crosstab_df = pd.crosstab(df['hotel'], df['market_segment'], normalize='index') * 100  
crosstab_df

# %% [markdown]
# Most City Hotel customers come through Online Travel Agencies (60%) while Resort Hotel customers are more likely to book directly or through corporate channels. This suggests that City Hotels rely more on online booking platforms
#
# The Corporate segment is relatively small in City Hotels (10%) but more noticeable in Resort Hotels (20%). This may reflect different market strategies for each hotel type.

# %%
crosstab_df = pd.crosstab(df['reserved_room_type'], df['assigned_room_type'], normalize='index') * 100
crosstab_df = pd.crosstab(df['market_segment'], df['distribution_channel'], normalize='index') * 100

# %% [markdown]
# Option 1: Reserved Room Type ↔ Assigned Room Type
#
# Most reservations are assigned the same room type that was originally booked, indicating that the hotel generally honors customer booking preferences.
#
# Some reservations are assigned different room types than originally reserved, which may occur due to room availability issues or operational adjustments by the hotel.
#
# Option 2: Market Segment ↔ Distribution Channel
#
# Certain market segments rely heavily on specific distribution channels, showing that different customer groups prefer different booking methods.
#
# Online Travel Agencies and direct channels often dominate bookings, suggesting that these channels play a key role in the hotel marketing and sales strategy.

# %%
missing_count = df.isna().sum()
missing_percent = (df.isna().sum() / len(df)) * 100
missing_table = pd.DataFrame({
    "Missing Count": missing_count,
    "Missing %": missing_percent})
missing_table = missing_table[missing_table["Missing Count"] > 0]
print(missing_table)
print(missing_table)
print("\n")

# %%
#Missing Values
print("Missing Values:")
issing_count = df.isna().sum()
issing_percent = (df.isna().sum() / len(df)) * 100
issing_table = pd.DataFrame({
    "Missing Count": missing_count,
    "Missing %": missing_percent})
missing_table = missing_table[missing_table["Missing Count"] > 0]
print(missing_table)
print("\n")


#Duplicate Rows
print(" Duplicate Rows:")
duplicates = df.duplicated().sum()
print("Number of duplicate rows:", duplicates)
print("\n")

#Outliers (IQR method for numeric columns)
print("Columns with Outliers:\n")

numeric_cols = df.select_dtypes(include=np.number).columns
for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    outliers = df[(df[col] < Q1 - 1.5*IQR) | (df[col] > Q3 + 1.5*IQR)]
    if len(outliers) > 0:
        print(f"{col}: {len(outliers)} outliers")

print("\n\n")

#Rare Categories (<3%)
print(" Rare Categories:")
cat_cols = df.select_dtypes(include=['object','category']).columns
for col in cat_cols:
    freq = df[col].value_counts(normalize=True)*100
    rare = freq[freq < 3]
    if len(rare) > 0:
        print(f"\nColumn: {col}")
        print(rare)
print("\n")

#Invalid Values (negative numbers where not expected)
print(" Possible Invalid Values (negative numbers):")
for col in numeric_cols:
    negatives = (df[col] < 0).sum()
    if negatives > 0:
        print(f"{col}: {negatives} negative values")

# %%
# 1. Define the order of months for better logical display
month_order = ['January', 'February', 'March', 'April', 'May', 'June', 
 'July', 'August', 'September', 'October', 'November', 'December']

# 2. Compute group mean and median (Categorical: 'arrival_date_month' | Numeric: 'adr')
monthly_analysis = df.groupby('arrival_date_month')['price as Average daily rate'].agg(['mean', 'median', 'count']).reindex(month_order).reset_index()

# 3. Display the grouped table (Deliverable: Grouped Table)
print("Table: Average Daily Rate (ADR) Trends by Arrival Month")
display(monthly_analysis)

# 4. Insights (Deliverable: 1–2 Insights)
print("\n--- Key Insights ---")

# Finding the peak month automatically
peak_month = monthly_analysis.loc[monthly_analysis['mean'].idxmax(), 'arrival_date_month']
peak_value = monthly_analysis['mean'].max()

print(f"1. Seasonality Effect: There is a clear seasonal impact on pricing. The peak average price occurs in {peak_month} (${peak_value:.2f}), likely due to the summer holiday season.")
print(f"2. Pricing Consistency: August shows the highest booking volume (count) and highest price, indicating it is the most profitable month for the hotels in this dataset.")


#WE will handle missing values in columns like country and agent and create new features
 #will build a predictive model to identify the key factors that lead to booking cancellations, using all available features like lead time, deposit type, and previous cancellation,And predict the suitable prices.

# %% [markdown]
# جابه 19:hashtag#Capacity-Price Cluster: There is a notable positive correlation (0.37) between total_guests and adr. This confirms that larger booking groups (families) drive significantly higher daily rates compared to individual guests.
#
# hashtag#Stay Duration Consistency: A strong correlation block (0.50) exists between stays_in_weekend_nights and stays_in_week_nights. This indicates that guests tend to have consistent stay patterns, often combining weekdays and weekends into a single long trip.
#
# hashtag#Cancellation Risk Factor: A positive correlation (0.29) is observed between lead_time and is_canceled. This highlights that bookings made far in advance carry a higher risk of cancellation, identifying lead_time as a critical feature for predictive modeling.

# %% [markdown]
# Top Five insights
#
# The Golden Insight (Lead Time Risk): The strongest predictor of cancellation is lead_time.
# Bookings made many months in advance carry a higher risk, suggesting the hotel should implement stricter deposit or insurance policies for long-term reservations.
#
# Pricing Strategy (Family Drivers): The average daily rate (adr) is more significantly influenced by the presence of children (0.35) than adults (0.29).
# This indicates that family-oriented pricing and room configurations are the primary drivers of the hotel's revenue.
#
# Guest Loyalty (Retention): There is a clear correlation between a clean booking history (no previous cancellations) and guest retention.
# This statistically confirms that ensuring high satisfaction during a guest's first visit is the most effective strategy for securing future loyalty and repeat business

# %% [markdown]
# High Missing Values in company
#
# The company column contains a very large number of missing values (over 90%), which makes it unreliable for analysis.
#
# Moderate Missing Values in agent
#
# The agent column has a noticeable number of missing values, which may affect analysis related to booking channels.
#
# Few Missing Values in country and children
#
# These columns contain a small number of missing values that need to be filled to maintain data completeness.
#
# Possible Outliers in adr (Average Daily Rate)
#
# Extremely high or very low values may exist and could distort pricing analysis.
#
# Inconsistent or Messy Labels in Categorical Columns
#
# Some categorical variables (such as market_segment or distribution_channel) may contain rare or inconsistent categories that need grouping or cleaning.

# %% [markdown]
# Q20) Final EDA Summary
# Top 5 Insights (Distributions + Relationships)
# Strong Seasonality: Average Daily Rate (ADR) peaks significantly in August ($140.14) compared to January ($70.36), showing a clear summer holiday impact on pricing.
#
# Capacity-Driven Pricing: There is a positive correlation (0.37) between total_guests and adr, proving that larger groups (families) lead to higher revenue per booking.
#
# Stay Duration Consistency: A strong correlation (0.50) between weekend and weekday stays suggests guests typically book long, continuous trips rather than isolated days.
#
# High-Volume Profitability: August is the most profitable month, combining the highest booking volume (13,873) with the highest average price.
#
# Guest Density Correlation: total_guests is highly correlated with adults (0.82) and children (0.58), showing that adult occupancy is the primary driver of group size.
#
# Top 5 Problems/Risks
# Cancellation Risk: lead_time shows a positive correlation (0.29) with is_canceled, indicating that long-term bookings are much more likely to be abandoned.
#
# Invalid Data Entries: The dataset contains records with total_guests of 0 yet shows an ADR of $10.45, which are logical errors in the data.
#
# Extreme Outliers: Some rows show extreme group sizes (e.g., 55 guests) with an ADR of $0, which can skew statistical modeling and average calculations.
#
# Missing Values: Essential columns like children required cleaning (fillna) to prevent calculation errors in the total_guests feature.
#
# Weak Correlation Features: Several variables show near-zero correlation with pricing or cancellations, suggesting they may need to be dropped during feature selection to avoid noise.
#
# What I would do next
# I will remove the identified outliers in adr and total_guests to ensure data quality, then proceed to build a classification model to predict is_canceled using high-impact features like lead_time and total_of_special_requests.
